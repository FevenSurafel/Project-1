# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# File to Load
nasdaq_data = "Resources/Main.csv"

# %%
# Read Data File and store into Pandas DataFrames
nasdaq_data_df = pd.read_csv(nasdaq_data)
nasdaq_data_df
# Out:
#             Date    Open      High       Low    Close    Volume  Ex-Dividend  \
# 0     12/29/2017  170.52  170.5900  169.2200  169.230  25643711          0.0
# 1     12/28/2017  171.00  171.8500  170.4800  171.080  15997739          0.0
# 2     12/27/2017  170.10  170.7800  169.7100  170.600  21672062          0.0
# 3     12/26/2017  170.80  171.4700  169.6790  170.570  32968167          0.0
# 4     12/22/2017  174.68  175.4240  174.5000  175.010  16052615          0.0
# ...          ...     ...       ...       ...      ...       ...          ...
# 7533    1/8/2015  212.81  213.7999  210.0100  210.615   3442509          0.0
# 7534    1/7/2015  213.35  214.7800  209.7800  210.950   2968390          0.0
# 7535    1/6/2015  210.06  214.2000  204.2100  211.280   6261936          0.0
# 7536    1/5/2015  214.55  216.5000  207.1626  210.090   5368477          0.0
# 7537    1/2/2015  222.87  223.2500  213.2600  219.310   4764443          0.0
#
# ...

# %%
stock_data = nasdaq_data_df['Company'].unique()
stock_data
# Out:
# array(['Apple', 'Amazon', 'Facebook', 'GameStop', 'Google', 'Microsoft',
#        'MicroStrategy', 'NetFlix', 'NVIDIA', 'Tesla'], dtype=object)

# %%
#Calcuate the Dividend Yield then create column
nasdaq_data_df["Dividend Yield"] = (nasdaq_data_df["Ex-Dividend"] / nasdaq_data_df['Close'])

nasdaq_data_df[nasdaq_data_df["Dividend Yield"] > 0]
# Out:
#             Date     Open      High       Low   Close    Volume  Ex-Dividend  \
# 97     8/10/2017  159.900  160.0000  154.6300  155.27  39081017       0.6300
# 159    5/11/2017  152.450  154.0700  152.3100  153.95  25596687       0.6300
# 222     2/9/2017  131.650  132.4450  131.1200  132.42  28349859       0.5700
# 288    11/3/2016  110.980  111.4600  109.5500  109.83  26932602       0.5700
# 352     8/4/2016  105.580  106.0000  105.2800  105.87  27408650       0.5700
# 415     5/5/2016   94.000   94.0700   92.6800   93.24  35890500       0.5700
# 478     2/4/2016   95.860   97.3300   95.1900   96.60  46471652       0.5200
# 539    11/5/2015  121.850  122.6900  120.1800  120.92  39552680       0.5200
# 603     8/6/2015  115.970  116.5000  114.1150  115.13  52903040       0.5200
# 666     5/7/2015  124.770  126.0800  124.0200  125.26  43940895       0.5200
# 729     2/5/2015  120.020  120.2300  119.2500  119.94  42246245       0.4700
# ...

# %%
grouped_stocks_df = nasdaq_data_df.groupby(["Company"])

# %%
div_yield = grouped_stocks_df["Dividend Yield"].mean()
div_yield
# Out:
# Company
# Amazon           0.000000
# Apple            0.000068
# Facebook         0.000000
# GameStop         0.000188
# Google           0.000000
# MicroStrategy    0.000000
# Microsoft        0.000101
# NVIDIA           0.000038
# NetFlix          0.000000
# Tesla            0.000000
# Name: Dividend Yield, dtype: float64

# %%
# Configure plot, figsize, title, and axis labels
figure1 = div_yield.plot(kind="bar", facecolor="purple", figsize=(8,6),
                                title="Dividend Yield for Different Stocks",
                                xlabel="Company",
                                ylabel="Dividend Yield (Mean)")

# Configure x-tick rotation
xticklabels = div_yield.index
figure1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)

# Show plot
plt.show()

# Resize plot to display labels
plt.tight_layout()
