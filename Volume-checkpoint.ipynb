# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# File to Load
nasdaq_data = "Resources/Main.csv"

# %%
# Read Data File and store into Pandas DataFrames
nasdaq_data_df = pd.read_csv(nasdaq_data)
nasdaq_data_df
# Out:
#             Date    Open      High       Low    Close    Volume  Ex-Dividend  \
# 0     12/29/2017  170.52  170.5900  169.2200  169.230  25643711          0.0
# 1     12/28/2017  171.00  171.8500  170.4800  171.080  15997739          0.0
# 2     12/27/2017  170.10  170.7800  169.7100  170.600  21672062          0.0
# 3     12/26/2017  170.80  171.4700  169.6790  170.570  32968167          0.0
# 4     12/22/2017  174.68  175.4240  174.5000  175.010  16052615          0.0
# ...          ...     ...       ...       ...      ...       ...          ...
# 7533    1/8/2015  212.81  213.7999  210.0100  210.615   3442509          0.0
# 7534    1/7/2015  213.35  214.7800  209.7800  210.950   2968390          0.0
# 7535    1/6/2015  210.06  214.2000  204.2100  211.280   6261936          0.0
# 7536    1/5/2015  214.55  216.5000  207.1626  210.090   5368477          0.0
# 7537    1/2/2015  222.87  223.2500  213.2600  219.310   4764443          0.0
#
# ...

# %%
# Calculate the average trading volume
average_volume = nasdaq_data_df['Volume'].mean()

# Set a threshold for unusually high activity (10x the average)
threshold = 10 * average_volume

# Filter days with trading volume above the threshold
unusually_high_volume_days = nasdaq_data_df[nasdaq_data_df['Volume'] > threshold]
unusually_high_volume_days
# Out:
#             Date     Open      High      Low   Close     Volume  Ex-Dividend  \
# 484    1/27/2016   96.040   96.6289   93.340   93.42  133369674          0.0
# 591    8/24/2015   94.870  108.8000   92.000  103.12  162206292          0.0
# 592    8/21/2015  110.430  111.9000  105.645  105.76  128275471          0.0
# 735    1/28/2015  117.625  118.1200  115.310  115.31  146477063          0.0
# 4149   6/24/2016   49.810   50.9400   49.520   49.83  133502985          0.0
# 4317  10/23/2015   52.300   54.0700   52.250   52.87  135227059          0.0
# 4444   4/24/2015   45.660   48.1400   45.650   47.87  130933665          0.0
# 4505   1/27/2015   42.950   43.2000   42.105   42.66  169163953          0.0
#
#       Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# 484           1.0   92.788919   93.357884   90.180318   90.257610
# 591           1.0   91.266048  104.666871   88.505074   99.202644
# 592           1.0  106.234950  107.649107  101.631724  101.742355
# ...

# %%
stock_data = nasdaq_data_df["Company"].unique()
stock_data
# Out:
# array(['Apple', 'Amazon', 'Facebook', 'GameStop', 'Google', 'Microsoft',
#        'MicroStrategy', 'NetFlix', 'NVIDIA', 'Tesla'], dtype=object)

# %%
unusually_high_volume_days

nasdaq_data_df = pd.DataFrame(unusually_high_volume_days)
nasdaq_data_df['Date'] = pd.to_datetime(nasdaq_data_df['Date'])

# Configure plot, figsize, title, and axis labels
plt.figure(figsize=(10, 5))
plt.plot(nasdaq_data_df['Date'], nasdaq_data_df['Volume'], marker='o', linestyle='-')
plt.title('Unusually High Volume Days')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)

# Show plot
plt.show()
